# %% [markdown]
# # Economic Anaylsis - Data Project
# **Creator: Cesar Gutierrez**
# **Contact Information: Cesargutierrez.email@gmail.com**
# **Data: https://www.kaggle.com/datasets/khushiyadav2022/top-countries-gdp-information**

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Top countries GDP info.csv')
df
# Out:
#      Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0             0  1980                2857.3                      12552.9
# 1             1  1981                3207.0                      13948.7
# 2             2  1982                3343.8                      14405.0
# 3             3  1983                3634.0                      15513.7
# 4             4  1984                4037.7                      17086.4
# ..          ...   ...                   ...                          ...
# 235         235  2023               13033.4                       9073.0
# 236         236  2024               14165.5                       9773.0
# 237         237  2025               15330.6                      10484.8
# 238         238  2026               16563.8                      11232.6
# 239         239  2027               17877.0                      12024.0
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# ...

# %%
df_clean = df.dropna()
df_clean
# Out:
#      Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 21           21  2001               10581.9                      37101.5
# 22           22  2002               10929.1                      37945.8
# 23           23  2003               11456.5                      39405.4
# 24           24  2004               12217.2                      41641.6
# 25           25  2005               13039.2                      44034.3
# ..          ...   ...                   ...                          ...
# 229         229  2017                8276.9                       6182.9
# 230         230  2018                9023.0                       6590.9
# 231         231  2019                9540.4                       6897.8
# 232         232  2020                9101.3                       6517.8
# 233         233  2021               10370.8                       7355.4
#
#      GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# ...

# %% [markdown]
# **U.S. Data**

# %%
df_US = df_clean[df_clean['Country'] == 'US']
df_US
# Out:
#     Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 21          21  2001               10581.9                      37101.5
# 22          22  2002               10929.1                      37945.8
# 23          23  2003               11456.5                      39405.4
# 24          24  2004               12217.2                      41641.6
# 25          25  2005               13039.2                      44034.3
# 26          26  2006               13815.6                      46216.9
# 27          27  2007               14474.3                      47943.4
# 28          28  2008               14769.9                      48470.6
# 29          29  2009               14478.1                      47102.4
# 30          30  2010               15049.0                      48586.3
# 31          31  2011               15599.7                      50008.1
# 32          32  2012               16254.0                      51736.7
# ...

# %%
df_US.plot(x='Year', y='GDP (in Bil. US$PPP)', kind='line', title='United States GDP from 2001 to 2027')
plt.show()

# %% [markdown]
# **China Data**

# %%
df_China = df_clean[df_clean['Country'] == 'China']
df_China
# Out:
#     Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 63          63  1995                2225.5                       1837.4
# 64          64  1996                2491.0                       2035.3
# 65          65  1997                2768.3                       2239.3
# 66          66  1998                3019.4                       2420.1
# 67          67  1999                3297.1                       2621.2
# 68          68  2000                3657.5                       2885.7
# 69          69  2001                4051.0                       3174.1
# 70          70  2002                4489.1                       3494.7
# 71          71  2003                5036.5                       3897.4
# 72          72  2004                5694.7                       4381.0
# 73          73  2005                6542.3                       5003.4
# 74          74  2006                7601.3                       5782.8
# ...

# %%
df_China.plot(x='Year', y='GDP (in Bil. US$PPP)', kind='line', title="China's GDP from 1995 to 2027")
plt.show()

# %% [markdown]
# **Japan Data**

# %%
df_Japan = df_clean[df_clean['Country'] == 'Japan']
df_Japan
# Out:
# C:\Users\Cesar Gutierrez\AppData\Local\Temp\ipykernel_30476\1270984018.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_Japan = df_clean[df['Country'] == 'Japan']
#      Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 96           96  1980                1068.1                       9147.0
# 97           97  1981                1218.4                      10358.1
# 98           98  1982                1336.5                      11283.0
# 99           99  1983                1437.8                      12054.5
# 100         100  1984                1556.7                      12967.1
# 101         101  1985                1690.0                      13989.8
# 102         102  1986                1781.4                      14667.9
# 103         103  1987                1911.8                      15666.3
# 104         104  1988                2113.5                      17246.0
# ...

# %%
df_Japan.plot(x='Year', y='GDP (in Bil. US$PPP)', kind='line', title="Japan's GDP from 1980 to 2027")
plt.show()

# %% [markdown]
# **India Data**

# %%
df_India = df_clean[df_clean['Country'] == 'India']
df_India
# Out:
# C:\Users\Cesar Gutierrez\AppData\Local\Temp\ipykernel_30476\2849308361.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_India = df_clean[df['Country'] == 'India']
#      Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 203         203  1991                1004.8                       1127.4
# 204         204  1992                1084.1                       1192.2
# 205         205  1993                1162.5                       1253.5
# 206         206  1994                1266.4                       1339.2
# 207         207  1995                1390.8                       1442.9
# 208         208  1996                1523.2                       1550.6
# 209         209  1997                1612.3                       1610.8
# 210         210  1998                1731.2                       1698.1
# 211         211  1999                1904.2                       1834.4
# ...

# %%
df_India.plot(x='Year', y='GDP (in Bil. US$PPP)', kind='line', title="India's GDP from 1995 to 2027")
plt.show()

# %%
df_Germany = df_clean[df_clean['Country'] == 'Germany']
df_Germany
# Out:
# C:\Users\Cesar Gutierrez\AppData\Local\Temp\ipykernel_30476\3214401931.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_Germany = df_clean[df['Country'] == 'Germany']
#      Unnamed: 0  Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 155         155  1991                1755.6                      21951.9
# 156         156  1992                1830.0                      22733.4
# 157         157  1993                1855.1                      22917.9
# 158         158  1994                1940.2                      23909.4
# 159         159  1995                2011.4                      24738.0
# 160         160  1996                2064.9                      25347.0
# 161         161  1997                2138.0                      26230.3
# 162         162  1998                2205.8                      27082.8
# 163         163  1999                2279.1                      27990.7
# ...

# %%
df_Germany.plot(x='Year', y='GDP (in Bil. US$PPP)', kind='line', title="Germany's GDP from 1991 to 2027")
plt.show()
